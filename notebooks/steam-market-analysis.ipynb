# %% [markdown]
# #### About
# ###### 1
# ###### 2
# ###### 3

# %% [markdown]
# ##### Loading Data
# ###### The first step is to loading data.

# %%
# %pip install kagglehub

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import kagglehub
import os
from IPython.display import display

# easy read 
pd.set_option('display.float_format', lambda x: '%.2f' % x)
# Download latest version
path = kagglehub.dataset_download("artermiloff/steam-games-dataset")
file_path = os.path.join(path, "games_march2025_full.csv")

# %%
dataset = pd.read_csv(file_path)

display(dataset)

display(dataset.info())
# Out:
#          appid                             name release_date  required_age  \
# 0          730                 Counter-Strike 2   2012-08-21             0
# 1       578080              PUBG: BATTLEGROUNDS   2017-12-21             0
# 2          570                           Dota 2   2013-07-09             0
# 3       271590        Grand Theft Auto V Legacy   2015-04-13            17
# 4       488824  Tom Clancy's Rainbow Six® Siege   2015-12-01            17
# ...        ...                              ...          ...           ...
# 94943  2115110                      Outrun Them   2024-02-29             0
# 94944  1174200      Lands of Pharaoh: Episode 1   2020-01-07             0
# 94945  1160190                       Player One   2019-10-10             0
# 94946  3380340                       DragonRoad   2025-01-25             0
# 94947   763730               Ragtag Adventurers   2018-03-01             0
#
#        price  dlc_count                               detailed_description  \
# 0       0.00          1  For over two decades, Counter-Strike has offer...
# 1       0.00          0  LAND, LOOT, SURVIVE! Play PUBG: BATTLEGROUNDS ...
# 2       0.00          2  The most-played game on Steam. Every day, mill...
# 3       0.00          0  When a young street hustler, a retired bank ro...
# 4      19.99          9  Edition Comparison Ultimate Edition The Tom Cl...
# ...      ...        ...                                                ...
# 94943   3.99          0  The name of the game is literally the game. Ou...
# 94944  10.00          0  Join Our Discord Channel About the Game Briefl...
# 94945   1.99          0  Player One is a new 3D game where you take con...
# 94946  29.99          0      This is an open world game on 3D, also a m...
# 94947   9.99          0  Ragtag Adventurers is a Boss Rush game that pi...
#
#                                           about_the_game  \
# 0      For over two decades, Counter-Strike has offer...
# 1      LAND, LOOT, SURVIVE! Play PUBG: BATTLEGROUNDS ...
# 2      The most-played game on Steam. Every day, mill...
# 3      When a young street hustler, a retired bank ro...
# 4      “One of the best first-person shooters ever ma...
# ...                                                  ...
# 94943  The name of the game is literally the game. Ou...
# 94944  Briefly: Lands of Pharaoh is a third person vi...
# 94945  Player One is a new 3D game where you take con...
# 94946      This is an open world game on 3D, also a m...
# 94947  Ragtag Adventurers is a Boss Rush game that pi...
#
#                                        short_description  \
# 0      For over two decades, Counter-Strike has offer...
# 1      Play PUBG: BATTLEGROUNDS for free. Land on str...
# 2      Every day, millions of players worldwide enter...
# 3      Grand Theft Auto V for PC offers players the o...
# 4      Tom Clancy's Rainbow Six® Siege is an elite, t...
# ...                                                  ...
# 94943                It's all in the name.. outrun them.
# 94944  Lands of Pharaoh is a multi-camera-angle based...
# 94945                    3D Game, Thirdperson Platformer
# 94946  This is an open world game on 3D, Also a missi...
# 94947  Ragtag Adventurers is a boss rush game that pi...
#
#                                                  reviews  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2      “A modern multiplayer masterpiece.” 9.5/10 – D...  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 94943                                                NaN  ...
# 94944                                                NaN  ...
# 94945                                                NaN  ...
# 94946                                                NaN  ...
# 94947                                                NaN  ...
#
#       average_playtime_2weeks median_playtime_forever median_playtime_2weeks  \
# 0                         879                    5174                    350
# 1                           0                       0                      0
# 2                        1536                     898                    892
# 3                         771                    7101                     74
# 4                           0                       0                      0
# ...                       ...                     ...                    ...
# 94943                       0                       0                      0
# 94944                       0                       0                      0
# 94945                       0                       0                      0
# 94946                       0                       0                      0
# 94947                       0                       0                      0
#
#       discount  peak_ccu                                               tags  \
# 0            0   1212356  {'FPS': 90857, 'Shooter': 65397, 'Multiplayer'...
# 1            0    616738  {'Survival': 14838, 'Shooter': 12727, 'Battle ...
# 2            0    555977  {'Free to Play': 59933, 'MOBA': 20158, 'Multip...
# 3            0    117698  {'Open World': 32644, 'Action': 23539, 'Multip...
# 4            0         0  {'FPS': 8082, 'Multiplayer': 6139, 'Tactical':...
# ...        ...       ...                                                ...
# 94943        0         0  {'2D Platformer': 91, 'Runner': 85, 'Platforme...
# 94944        0         0  {'Action': 43, 'Adventure': 41, 'Indie': 41, '...
# 94945        0         0                  {'Indie': 31, 'Early Access': 21}
# 94946        0         0  {'RPG': 117, 'Action-Adventure': 111, 'Strateg...
# 94947        0         0                        {'Action': 22, 'Indie': 21}
#
#        pct_pos_total  num_reviews_total pct_pos_recent  num_reviews_recent
# 0                 86            8632939             82               96473
# 1                 59            2513842             68               16720
# 2                 81            2452595             80               29366
# 3                 87            1803832             92               17517
# 4                 84            1168404             76               13017
# ...              ...                ...            ...                 ...
# 94943             -1                 -1             -1                  -1
# 94944             -1                 -1             -1                  -1
# 94945             -1                 -1             -1                  -1
# 94946             -1                 -1             -1                  -1
# 94947             -1                 -1             -1                  -1
#
# [94948 rows x 47 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94948 entries, 0 to 94947
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     94948 non-null  int64
#  1   name                      94946 non-null  object
#  2   release_date              94948 non-null  object
#  3   required_age              94948 non-null  int64
#  4   price                     94948 non-null  float64
#  5   dlc_count                 94948 non-null  int64
#  6   detailed_description      89522 non-null  object
#  7   about_the_game            89499 non-null  object
#  8   short_description         89599 non-null  object
#  9   reviews                   10428 non-null  object
#  10  header_image              94948 non-null  object
#  11  website                   41194 non-null  object
#  12  support_url               44185 non-null  object
#  13  support_email             78848 non-null  object
#  14  windows                   94948 non-null  bool
#  15  mac                       94948 non-null  bool
#  16  linux                     94948 non-null  bool
#  17  metacritic_score          94948 non-null  int64
#  18  metacritic_url            3576 non-null   object
#  19  achievements              94948 non-null  int64
#  20  recommendations           94948 non-null  int64
#  21  notes                     16652 non-null  object
#  22  supported_languages       94948 non-null  object
#  23  full_audio_languages      94948 non-null  object
#  24  packages                  94948 non-null  object
#  25  developers                94948 non-null  object
#  26  publishers                94948 non-null  object
#  27  categories                94948 non-null  object
#  28  genres                    94948 non-null  object
#  29  screenshots               94948 non-null  object
#  30  movies                    94948 non-null  object
#  31  user_score                94948 non-null  int64
#  32  score_rank                39 non-null     float64
#  33  positive                  94948 non-null  int64
#  34  negative                  94948 non-null  int64
#  35  estimated_owners          94948 non-null  object
#  36  average_playtime_forever  94948 non-null  int64
#  37  average_playtime_2weeks   94948 non-null  int64
#  38  median_playtime_forever   94948 non-null  int64
#  39  median_playtime_2weeks    94948 non-null  int64
#  40  discount                  94948 non-null  int64
#  41  peak_ccu                  94948 non-null  int64
#  42  tags                      94948 non-null  object
#  43  pct_pos_total             94948 non-null  int64
#  44  num_reviews_total         94948 non-null  int64
#  45  pct_pos_recent            94948 non-null  int64
#  46  num_reviews_recent        94948 non-null  int64
# dtypes: bool(3), float64(2), int64(19), object(23)
# memory usage: 32.1+ MB
# None

# %% [markdown]
# ##### Data Description

# %%
dataset.describe()
# Out:
#            appid  required_age    price  dlc_count  metacritic_score  \
# count   94948.00      94948.00 94948.00   94948.00          94948.00
# mean  1707530.53          0.18     6.91       0.56              2.76
# std    926434.62          1.70    13.07      14.92             14.11
# min        20.00         -1.00     0.00       0.00              0.00
# 25%    887337.50          0.00     0.99       0.00              0.00
# 50%   1591145.00          0.00     3.99       0.00              0.00
# 75%   2491702.50          0.00     9.99       0.00              0.00
# max   3570420.00         21.00   999.98    3427.00             97.00
#
#        achievements  recommendations  user_score  score_rank   positive  ...  \
# count      94948.00         94948.00    94948.00       39.00   94948.00  ...
# mean          19.54          1022.21        0.03       99.13    1217.90  ...
# std          159.80         22741.51        1.57        0.70   30979.74  ...
# min            0.00             0.00        0.00       98.00       0.00  ...
# 25%            0.00             0.00        0.00       99.00       0.00  ...
# 50%            2.00             0.00        0.00       99.00       8.00  ...
# 75%           19.00             0.00        0.00      100.00      51.00  ...
# max         9821.00       4401572.00      100.00      100.00 7480813.00  ...
#
#        average_playtime_forever  average_playtime_2weeks  \
# count                  94948.00                 94948.00
# mean                     108.61                     4.76
# std                     6620.83                   175.96
# min                        0.00                     0.00
# 25%                        0.00                     0.00
# 50%                        0.00                     0.00
# 75%                        0.00                     0.00
# max                  1462997.00                 18568.00
#
#        median_playtime_forever  median_playtime_2weeks  discount   peak_ccu  \
# count                 94948.00                94948.00  94948.00   94948.00
# mean                    108.37                    5.02      4.31      92.85
# std                    8555.99                  184.24     16.11    5554.79
# min                       0.00                    0.00      0.00       0.00
# 25%                       0.00                    0.00      0.00       0.00
# 50%                       0.00                    0.00      0.00       0.00
# 75%                       0.00                    0.00      0.00       0.00
# max                 1462997.00                18568.00    100.00 1212356.00
#
#        pct_pos_total  num_reviews_total  pct_pos_recent  num_reviews_recent
# count       94948.00           94948.00        94948.00            94948.00
# mean           44.63            1448.04            5.33               16.88
# std            40.84           35481.41           22.46              459.11
# min            -1.00              -1.00           -1.00               -1.00
# 25%            -1.00              -1.00           -1.00               -1.00
# 50%            58.00              15.00           -1.00               -1.00
# 75%            84.00              80.00           -1.00               -1.00
# max           100.00         8632939.00          100.00            96473.00
#
# [8 rows x 21 columns]
