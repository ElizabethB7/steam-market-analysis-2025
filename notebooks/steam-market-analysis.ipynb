# %% [markdown]
# #### About
# ###### 1
# ###### 2
# ###### 3

# %% [markdown]
# ##### Loading Data
# ###### The first step is to loading data.

# %%
# %pip install kagglehub

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
